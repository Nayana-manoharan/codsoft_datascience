# %% [markdown]
# <a href="https://colab.research.google.com/github/Nayana-manoharan/codsoft_datascience/blob/main/ds_iris.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
# first upload file
df=pd.read_csv("/content/IRIS.csv")
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
df.tail()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica

# %%
df.shape
# Out:
# (150, 5)

# %%
df.isna().sum()  #total number of missing value
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
df.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
df1=df.groupby('species') ['species'].count() #SELECT INPUT
df1
# Out:
# species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: species, dtype: int64

# %%
x=df.iloc[:,:-1].values #.values used to print as array
x
y=df.iloc[:,-1].values
y
# Out:
# array(['Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-versicolor', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor',
# ...

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30)
x_train
# Out:
# array([[6.3, 3.4, 5.6, 2.4],
#        [7.2, 3. , 5.8, 1.6],
#        [5.4, 3.7, 1.5, 0.2],
#        [4.8, 3.4, 1.9, 0.2],
#        [5. , 3.6, 1.4, 0.2],
#        [5.5, 2.4, 3.7, 1. ],
#        [6.2, 2.9, 4.3, 1.3],
#        [6.7, 2.5, 5.8, 1.8],
#        [6.7, 3. , 5. , 1.7],
#        [5.1, 3.8, 1.5, 0.3],
#        [5. , 3.2, 1.2, 0.2],
#        [5.6, 3. , 4.1, 1.3],
#        [6. , 3.4, 4.5, 1.6],
#        [6.5, 2.8, 4.6, 1.5],
#        [5.4, 3. , 4.5, 1.5],
#        [4.8, 3.4, 1.6, 0.2],
#        [5.7, 2.9, 4.2, 1.3],
#        [5. , 3.4, 1.6, 0.4],
#        [7.7, 2.6, 6.9, 2.3],
#        [7.3, 2.9, 6.3, 1.8],
#        [5.7, 2.6, 3.5, 1. ],
#        [6. , 2.7, 5.1, 1.6],
#        [7.9, 3.8, 6.4, 2. ],
#        [5. , 3.5, 1.6, 0.6],
#        [4.8, 3. , 1.4, 0.1],
#        [6.4, 2.7, 5.3, 1.9],
#        [6.9, 3.1, 5.4, 2.1],
#        [6.5, 3. , 5.2, 2. ],
#        [5.7, 3. , 4.2, 1.2],
#        [5. , 3. , 1.6, 0.2],
#        [6.2, 2.8, 4.8, 1.8],
#        [6.2, 2.2, 4.5, 1.5],
# ...

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
scaler.fit(x_train)
x_train=scaler.transform(x_train)
x_test=scaler.transform(x_test)
x_train
# Out:
# array([[ 0.49927176,  0.69388983,  1.02775119,  1.57358515],
#        [ 1.57893267, -0.18392261,  1.13963701,  0.52867485],
#        [-0.58038914,  1.35224916, -1.26590815, -1.29991816],
#        [-1.30016308,  0.69388983, -1.04213651, -1.29991816],
#        [-1.06023844,  1.13279605, -1.32185106, -1.29991816],
#        [-0.46042682, -1.50064126, -0.03516412, -0.25500787],
#        [ 0.37930944, -0.40337572,  0.30049335,  0.13683349],
#        [ 0.97912106, -1.28118815,  1.13963701,  0.78990243],
#        [ 0.97912106, -0.18392261,  0.69209372,  0.65928864],
#        [-0.94027611,  1.57170227, -1.26590815, -1.16930438],
#        [-1.06023844,  0.25498361, -1.43373688, -1.29991816],
#        [-0.3404645 , -0.18392261,  0.18860753,  0.13683349],
#        [ 0.13938479,  0.69388983,  0.41237917,  0.52867485],
#        [ 0.73919641, -0.62282883,  0.46832208,  0.39806106],
#        [-0.58038914, -0.18392261,  0.41237917,  0.39806106],
# ...

# %% [markdown]
# # **KNN**

# %%
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier(n_neighbors=6)
# fit input and output
knn.fit(x_train,y_train)
# predict the y value
y_predict=knn.predict(x_test)
y_predict
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica',
#        'Iris-virginica', 'Iris-virginica', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-setosa', 'Iris-versicolor', 'Iris-setosa',
#        'Iris-setosa', 'Iris-virginica', 'Iris-virginica',
#        'Iris-versicolor', 'Iris-setosa', 'Iris-setosa', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-virginica', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-setosa',
#        'Iris-virginica', 'Iris-setosa', 'Iris-virginica',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-setosa',
#        'Iris-virginica', 'Iris-versicolor', 'Iris-versicolor',
#        'Iris-setosa', 'Iris-virginica', 'Iris-versicolor',
#        'Iris-virginica', 'Iris-versicolor', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-versicolor', 'Iris-virginica',
#        'Iris-virginica', 'Iris-virginica'], dtype=object)

# %%
from sklearn.metrics import confusion_matrix,accuracy_score,ConfusionMatrixDisplay #(CONFUTION MATRIX DISPLAY IS USED TO PLOAT THE MATRICS)
label=['iris-setosa','iris-versicolor','iris-virginica']
mat=confusion_matrix(y_predict,y_test) #assign the variables
mat
cmd=ConfusionMatrixDisplay(mat,display_labels=label)
cmd.plot() #to plot
score=accuracy_score(y_predict,y_test)
score
# Out:
# 0.9777777777777777

# %% [markdown]
# # **Naive_bayes**

# %%
from sklearn.naive_bayes import GaussianNB
model=GaussianNB()
model.fit(x_train,y_train)
y_pred=model.predict(x_test)
y_pred
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica',
#        'Iris-virginica', 'Iris-virginica', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-setosa', 'Iris-versicolor', 'Iris-setosa',
#        'Iris-setosa', 'Iris-virginica', 'Iris-virginica',
#        'Iris-versicolor', 'Iris-setosa', 'Iris-setosa', 'Iris-virginica',
#        'Iris-versicolor', 'Iris-virginica', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-setosa',
#        'Iris-virginica', 'Iris-setosa', 'Iris-virginica',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-setosa',
#        'Iris-virginica', 'Iris-versicolor', 'Iris-versicolor',
#        'Iris-setosa', 'Iris-virginica', 'Iris-versicolor',
#        'Iris-virginica', 'Iris-versicolor', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-versicolor', 'Iris-virginica',
#        'Iris-virginica', 'Iris-virginica'], dtype='<U15')

# %%
# CREATE CONFUSION MATRIX
from sklearn.metrics import confusion_matrix,accuracy_score
mat=confusion_matrix(y_pred,y_test)
score=accuracy_score(y_pred,y_test)
score
# Out:
# 0.9555555555555556

# %% [markdown]
# # **Decition tree**

# %%
from sklearn.tree import DecisionTreeClassifier
model=DecisionTreeClassifier(criterion='entropy')
model.fit(x_train,y_train)
y_predict=model.predict(x_test)
y_predict
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica',
#        'Iris-virginica', 'Iris-virginica', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-setosa', 'Iris-versicolor', 'Iris-setosa',
#        'Iris-setosa', 'Iris-virginica', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-setosa', 'Iris-setosa', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-virginica', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-setosa',
#        'Iris-virginica', 'Iris-setosa', 'Iris-virginica',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-setosa',
#        'Iris-virginica', 'Iris-virginica', 'Iris-versicolor',
#        'Iris-setosa', 'Iris-virginica', 'Iris-versicolor',
#        'Iris-virginica', 'Iris-versicolor', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-versicolor', 'Iris-virginica',
#        'Iris-virginica', 'Iris-virginica'], dtype=object)

# %%
from sklearn.metrics import confusion_matrix,accuracy_score,ConfusionMatrixDisplay
label=['iris-setosa','iris-versicolor','iris-virginica']
mat=confusion_matrix(y_predict,y_test)
mat
cmd=ConfusionMatrixDisplay(mat,display_labels=label)
cmd.plot() #to plot
score=accuracy_score(y_predict,y_test)
score
# Out:
# 0.9333333333333333

# %%
# to plot tree
from sklearn import tree
import matplotlib.pyplot as plt
plt.figure(figsize=(40,15))
tree.plot_tree(model,feature_names=['SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm'],class_names=['iris-setosa','iris-versicolor','iris-virginica'],filled=True)
# Out:
# [Text(0.4444444444444444, 0.9285714285714286, 'PetalWidthCm <= -0.516\nentropy = 1.585\nsamples = 105\nvalue = [36, 34, 35]\nclass = iris-setosa'),
#  Text(0.3333333333333333, 0.7857142857142857, 'entropy = 0.0\nsamples = 36\nvalue = [36, 0, 0]\nclass = iris-setosa'),
#  Text(0.5555555555555556, 0.7857142857142857, 'PetalLengthCm <= 0.552\nentropy = 1.0\nsamples = 69\nvalue = [0, 34, 35]\nclass = iris-virginica'),
#  Text(0.4444444444444444, 0.6428571428571429, 'entropy = 0.0\nsamples = 30\nvalue = [0, 30, 0]\nclass = iris-versicolor'),
#  Text(0.6666666666666666, 0.6428571428571429, 'PetalLengthCm <= 0.776\nentropy = 0.477\nsamples = 39\nvalue = [0, 4, 35]\nclass = iris-virginica'),
#  Text(0.5555555555555556, 0.5, 'PetalWidthCm <= 0.725\nentropy = 0.863\nsamples = 14\nvalue = [0, 4, 10]\nclass = iris-virginica'),
#  Text(0.3333333333333333, 0.35714285714285715, 'SepalLengthCm <= 0.739\nentropy = 0.971\nsamples = 5\nvalue = [0, 3, 2]\nclass = iris-versicolor'),
# ...
